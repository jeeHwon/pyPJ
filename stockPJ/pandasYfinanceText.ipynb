# %%
from pandas_datareader import data as pdr 
import yfinance as yf
yf.pdr_override
sec = pdr.get_data_yahoo('005930.KS', start='2018-05-04')
msft = pdr.get_data_yahoo('MSFT', start='2018-05-04')

# %%
import matplotlib.pyplot as plt 
sec_dpc = (sec['Close']-sec['Close'].shift(1)) / sec['Close'].shift(1) *100
sec_dpc.iloc[0] = 0
plt.hist(sec_dpc, bins=18)
plt.grid(True)
plt.show()
sec_dpc.describe()
# Out:
# count    624.000000
# mean       0.050274
# std        1.747452
# min       -6.387665
# 25%       -0.997182
# 50%        0.050556
# 75%        1.029632
# max       10.470588
# Name: Close, dtype: float64

# %%
sec_dpc_cs = sec_dpc.cumsum()
sec_dpc_cs
# Out:
# Date
# 2018-05-04     0.000000
# 2018-05-08     1.348748
# 2018-05-09    -1.883192
# 2018-05-10    -0.507946
# 2018-05-11    -1.089341
#                 ...
# 2020-11-13    29.049665
# 2020-11-16    33.954728
# 2020-11-17    33.049750
# 2020-11-18    31.679887
# 2020-11-19    31.371245
# Name: Close, Length: 624, dtype: float64

# %%
from pandas_datareader import data as pdr 
import yfinance as yf
yf.pdr_override

sec = pdr.get_data_yahoo('005930.KS', start='2018-05-04')
sec_dpc = (sec['Close']-sec['Close'].shift(1)) / sec['Close'].shift(1) *100
sec_dpc.iloc[0] = 0
sec_dpc_cs = sec_dpc.cumsum()

msft = pdr.get_data_yahoo('MSFT', start='2018-05-04')
msft_dpc = (msft['Close']-msft['Close'].shift(1)) / msft['Close'].shift(1) *100
msft_dpc.iloc[0] = 0
msft_dpc_cs = msft_dpc.cumsum()

import matplotlib.pyplot as plt 
plt.plot(sec.index, sec_dpc_cs, 'b', label='Samsung Electronics')
plt.plot(msft.index, msft_dpc_cs, 'r--', label='Microsoft')
plt.ylabel('Change %')
plt.grid(True)
plt.legend(loc='best')
plt.show()
